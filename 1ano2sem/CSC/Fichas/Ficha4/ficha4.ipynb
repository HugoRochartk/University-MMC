# %% [markdown]
# ***********************
# Importing the libraries.
# ***********************

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ***********************
# Set the Random Seed
# ***********************

# %%
#TODO

# %% [markdown]
# ***********************
# Load the dataset
# ***********************

# %%
#TODO
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ***********************
# Display the dataset
# ***********************

# %%
#TODO

print('***** Log data shape *****')
print('Train data shape', x_train.shape)
print('Test data shape', x_test.shape)
print('Number of training samples', x_train.shape[0])
print('Number of testing samples', x_test.shape[0])
print('The labels...', y_train)
print('**************************')
# Out:
# ***** Log data shape *****
# Train data shape (60000, 28, 28)
# Test data shape (10000, 28, 28)
# Number of training samples 60000
# Number of testing samples 10000
# The labels... [9 0 0 ... 3 0 5]
# *************************

# %% [markdown]
# ***********************
# Preprocessing the dataset
# ***********************

# %%
x_train = #TODO
x_test = #TODO

# %% [markdown]
# ***********************
# Building the model - the SEQUENTIAL API
# ***********************

# %%
model = tf.keras.Sequential([
    #TODO
])

# %% [markdown]
# ***********************
# Compiling the model
# ***********************

# %%
model.compile(#TODO)

# %% [markdown]
# ***********************
# Fit the model
# ***********************

# %%
model.fit(#TODO)
# Out:
# Epoch 1/5
# 1688/1688 [==============================] - 2s 1ms/step - loss: 0.5107 - accuracy: 0.8174 - val_loss: 0.4058 - val_accuracy: 0.8517
# Epoch 2/5
# 1688/1688 [==============================] - 2s 1ms/step - loss: 0.3797 - accuracy: 0.8613 - val_loss: 0.3917 - val_accuracy: 0.8508
# Epoch 3/5
# 1688/1688 [==============================] - 2s 1ms/step - loss: 0.3404 - accuracy: 0.8744 - val_loss: 0.3545 - val_accuracy: 0.8688
# Epoch 4/5
# 1688/1688 [==============================] - 2s 1ms/step - loss: 0.3189 - accuracy: 0.8814 - val_loss: 0.3383 - val_accuracy: 0.8772
# Epoch 5/5
# 1688/1688 [==============================] - 2s 1ms/step - loss: 0.2992 - accuracy: 0.8888 - val_loss: 0.3377 - val_accuracy: 0.8762

# %% [markdown]
# ***********************
# Evaluate the model
# ***********************

# %%
test_loss, test_acc = model.evaluate(#TODO)
# Out:
# 313/313 - 0s - loss: 0.3624 - accuracy: 0.8700

# %% [markdown]
# ***********************
# Obtain some predictions using the model
# ***********************

# %%
predictions = model.predict(x_test[:10])

for i, prediction in enumerate(predictions):
    predicted_value = #TODO
    predicted_label = #TODO
    real_label = #TODO
    print('Predicted label: ', predicted_label, '|| Real label: ', real_label)
# Out:
# Predicted label:  Ankle boot || Real label:  Ankle boot
# Predicted label:  Pullover || Real label:  Pullover
# Predicted label:  Trouser || Real label:  Trouser
# Predicted label:  Trouser || Real label:  Trouser
# Predicted label:  Shirt || Real label:  Shirt
# Predicted label:  Trouser || Real label:  Trouser
# Predicted label:  Coat || Real label:  Coat
# Predicted label:  Shirt || Real label:  Shirt
# Predicted label:  Sandal || Real label:  Sandal
# Predicted label:  Sneaker || Real label:  Sneaker
